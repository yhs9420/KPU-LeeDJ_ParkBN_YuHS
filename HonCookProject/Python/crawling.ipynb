# %%
# !pip install icrawler
from icrawler.builtin import BingImageCrawler

# %%
bing_crawler = BingImageCrawler(downloader_threads=4,storage={'root_dir': "./drive/My Drive/ingredient/frozen pollack fish"})
bing_crawler.crawl(keyword="frozen pollack fish", filters=None, offset=0, max_num=1000)
